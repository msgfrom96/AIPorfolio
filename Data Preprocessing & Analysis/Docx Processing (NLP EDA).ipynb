# %%
from docx import Document
from base64 import b64encode, decode

def process_word_file(word_file):
    """
    Extracts paragraphs, tables, images, lists, and other content from a DOCX file.

    Parameters:
        word_file (str): The path to the DOCX file to be processed.

    Returns:
        list: A list containing dictionaries for different content types, maintaining their order.
    """
    document = Document(word_file)

    content = []

    # Extract paragraphs
    for paragraph in document.paragraphs:
        content.append({"type": "paragraph", "text": paragraph.text})

    # Extract images
    for rel in document.part.rels.values():
        if "image" in rel.reltype:
            image_data = rel.target_part.blob
            encoded_image = b64encode(image_data).decode('utf-8')
            content.append({"type": "image", "data": encoded_image})

    # Extract tables
    for table in document.tables:
        table_data = []
        for row in table.rows:
            row_data = [cell.text for cell in row.cells]
            table_data.append(row_data)
        content.append({"type": "table", "data": table_data})

    # Extract lists (ordered and unordered)
    for paragraph in document.paragraphs:
        if paragraph.style.name.startswith('List'):
            content.append({"type": "list_item", "text": paragraph.text})

    # Extract headers and footers
    for section in document.sections:
        if section.header:
            for paragraph in section.header.paragraphs:
                content.append({"type": "header", "text": paragraph.text})
        if section.footer:
            for paragraph in section.footer.paragraphs:
                content.append({"type": "footer", "text": paragraph.text})

    # Clear local variables to release memory only if they have been initialized
    for var in ['document', 'paragraph', 'rel', 'row', 'row_data', 'section']:
        if var in locals():
            del locals()[var]

    return content

# %%
import tkinter as tk
from tkinter import filedialog

file = filedialog.askopenfilename(title="Select a DOCX file", filetypes=[("DOCX files", "*.docx")])

# %%
process_word_file(file)
# Out:
# [{'type': 'paragraph', 'text': 'Section 1: Tokenization issues'},
#  {'type': 'paragraph', 'text': '1. Addition'},
#  {'type': 'paragraph', 'text': ''},
#  {'type': 'paragraph',
#   'text': 'Question: Liam has 37 apples, and Sarah gives him 25 more. How many apples does Liam have now?'},
#  {'type': 'paragraph', 'text': 'Answer:'},
#  {'type': 'paragraph', 'text': '37 + 25 = 62'},
#  {'type': 'paragraph', 'text': 'Liam has 62 apples.'},
#  {'type': 'paragraph', 'text': ''},
#  {'type': 'paragraph', 'text': '2. Subtraction'},
#  {'type': 'paragraph', 'text': ''},
#  {'type': 'paragraph',
#   'text': 'Question: A library has 152 books. 47 books are borrowed by students. How many books are left in the library?'},
#  {'type': 'paragraph', 'text': ''},
#  {'type': 'paragraph', 'text': 'Answer:'},
#  {'type': 'paragraph', 'text': ''},
#  {'type': 'paragraph', 'text': '152 - 47 = 105'},
#  {'type': 'paragraph', 'text': 'The library has 105 books left.'},
#  {'type': 'paragraph', 'text': ''},
#  {'type': 'paragraph', 'text': '3. Multiplication'},
#  {'type': 'paragraph', 'text': ''},
#  {'type': 'paragraph', 'text': 'Question: '},
#  {'type': 'paragraph', 'text': ''},
#  {'type': 'paragraph',
#   'text': 'Each basket holds 8 oranges. How many oranges are there in 9 baskets?'},
#  {'type': 'paragraph', 'text': 'Answer:'},
#  {'type': 'paragraph', 'text': ''},
#  {'type': 'paragraph', 'text': '8 × 9 = 72'},
#  {'type': 'paragraph', 'text': 'There are 72 oranges in total.'},
#  {'type': 'paragraph', 'text': ''},
#  {'type': 'paragraph', 'text': '4. Division'},
#  {'type': 'paragraph', 'text': ''},
#  {'type': 'paragraph',
#   'text': 'Question: Emma has 48 candies, and she wants to share them equally with her 6 friends. How many candies will each friend get?'},
#  {'type': 'paragraph', 'text': ''},
#  {'type': 'paragraph', 'text': 'Answer:'},
#  {'type': 'paragraph', 'text': '48 ÷ 6 = 8'},
#  {'type': 'paragraph', 'text': 'Each friend will get 8 candies.'},
#  {'type': 'paragraph', 'text': ''},
#  {'type': 'paragraph', 'text': '5. Word Problem'},
#  {'type': 'paragraph', 'text': ''},
#  {'type': 'paragraph',
#   'text': 'Question: A farmer planted 15 rows of carrots. Each row has 12 carrots. If 10 carrots were eaten by rabbits, how many carrots are left?'},
#  {'type': 'paragraph',
#   'text': 'Answer: Step 1: Total carrots = 15 × 12 = 180'},
#  {'type': 'paragraph',
#   'text': 'Step 2: Remaining carrots = 180 - 10 = 170. There are 170 carrots left.Section 2: Image Reading'},
#  {'type': 'paragraph', 'text': ''},
#  {'type': 'paragraph',
#   'text': 'The image is a line graph illustrating monthly trends in the production of different types of produce. Here are its key features:'},
#  {'type': 'paragraph',
#   'text': '\t1.\tX-Axis (Horizontal): Represents time, specifically months (e.g., Oct 2019 through June 2020).'},
#  {'type': 'paragraph',
#   'text': '\t2.\tY-Axis (Vertical): Represents the quantity of produce, in USD'},
#  {'type': 'paragraph', 'text': '\t'},
#  {'type': 'paragraph', 'text': ''},
#  {'type': 'paragraph', 'text': ''},
#  {'type': 'paragraph', 'text': ''},
#  {'type': 'paragraph', 'text': 'Section 3: Paragraph Separation'},
#  {'type': 'paragraph', 'text': '\t1.\tShort Answer'},
#  {'type': 'paragraph',
#   'text': 'Combine the following sentences into a coherent paragraph:'},
#  {'type': 'paragraph', 'text': '\t•\tMath is fundamental to science.'},
#  {'type': 'paragraph', 'text': '\t•\tNumbers guide business decisions.'},
#  {'type': 'paragraph', 'text': '\t•\t“”'},
#  {'type': 'paragraph',
#   'text': '\t•\tIn 2022, math-related fields grew by 18%.'},
#  {'type': 'paragraph', 'text': ''},
#  {'type': 'paragraph', 'text': 'Section 4: Table'},
#  {'type': 'paragraph', 'text': ''},
#  {'type': 'paragraph', 'text': ''},
#  {'type': 'image',
#   'data': '...'},
#  {'type': 'table',
#   'data': [['Month', 'Sales ($)'],
#    ['January', '1000'],
#    ['February', '1500'],
#    ['March', 'N/A'],
#    ['April', '2500'],
#    ['January', '1000'],
#    ['February', '1500'],
#    ['March', 'N/A'],
#    ['April', '2500'],
#    ['January', '1000'],
#    ['February', '1500'],
#    ['March', 'N/A'],
#    ['April', '2500'],
#    ['January', '1000'],
#    ['February', '1500'],
#    ['March', 'N/A'],
#    ['April', '2500'],
#    ['January', '1000'],
#    ['February', '1500'],
#    ['March', 'N/A'],
#    ['April', '2500']]},
#  {'type': 'header', 'text': ''},
#  {'type': 'footer', 'text': ''}]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
