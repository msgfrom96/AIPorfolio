# %% [markdown]
# ## Maurice S. Gleiser
#
# <details>
# <summary>Motivation</summary>
#
# One often overlooked skill in machine learning is the importance of mapping out a thorough analysis plan before diving into a project. Skipping this step can lead to missed objectives, inefficiencies, and wasted resources. To avoid these pitfalls, the first hands-on exercise is designed to help you create a reusable machine learning template within a Jupyter Notebook (Google Colab). This template should emphasize markdown, with minimal code, serving as an outline for future projects. By mastering the structure and steps of a complete machine learning engagement, you’ll ensure that your projects remain organized, transparent, and replicable.
#
# The template should focus on four major components: problem definition, data preparation (Exploratory Data Analysis, or EDA), model selection and training, and model evaluation. Each section acts as a placeholder to guide your workflow and structure the machine learning process from start to finish. Remember, a well-organized plan demonstrates these skills more effectively than code alone.
#
# </details>

# %% [markdown]
# # Table of Contents
# <h2><b>1. <a href="#hands-on-exercise-1" style="color: inherit; text-decoration: none;">Hands-on Exercise 1</a></b></h2>
# <h2><b>2. <a href="#problem-introduction" style="color: inherit; text-decoration: none;">Problem Introduction</a></b></h2>
# <ul>
#     <li><h3><b><a href="#problem-definition" style="color: inherit; text-decoration: none;">Problem Definition</a></b></h3></li>
#     <li><h3><b><a href="#details" style="color: inherit; text-decoration: none;">Details</a></b></h3></li>
# </ul>
# <h2><b>3. <a href="#motivation" style="color: inherit; text-decoration: none;">Motivation</a></b></h2>
# <h2><b>4. <a href="#tasks" style="color: inherit; text-decoration: none;">Tasks</a></b></h2>
# <h2><b>5. <a href="#data-preparation-eda" style="color: inherit; text-decoration: none;">Data Preparation (EDA)</a></b></h2>
# <ul>
#     <li><h3><b><a href="#import-the-necessary-packages" style="color: inherit; text-decoration: none;">Import the necessary packages</a></b></h3></li>
#     <li><h3><b><a href="#load-the-dataset" style="color: inherit; text-decoration: none;">Load the dataset</a></b></h3></li>
#     <li><h3><b><a href="#understand-the-data-get-a-snapshot-and-see-the-data-types" style="color: inherit; text-decoration: none;">Understand the data, get a snapshot and see the data types</a></b></h3></li>
#     <li><h3><b><a href="#data-cleaning" style="color: inherit; text-decoration: none;">Data Cleaning</a></b></h3></li>
#     <li><h3><b><a href="#handling-missing-data" style="color: inherit; text-decoration: none;">Handling Missing Data</a></b></h3></li>
#     <li><h3><b><a href="#transforming" style="color: inherit; text-decoration: none;">Transforming</a></b></h3></li>
#     <li><h3><b><a href="#summarizing-and-visualization" style="color: inherit; text-decoration: none;">Summarizing and Visualization</a></b></h3></li>
# </ul>
# <h2><b>6. <a href="#model-selection" style="color: inherit; text-decoration: none;">Model Selection</a></b></h2>
# <ul>
#     <li><h3><b><a href="#model-choice" style="color: inherit; text-decoration: none;">Model Choice</a></b></h3></li>
# </ul>
# <h2><b>7. <a href="#model-evaluation" style="color: inherit; text-decoration: none;">Model Evaluation</a></b></h2>

# %% [markdown]
# # Problem Introduction
#
# <details open>
# <summary h1>Problem Introduction</summary>
# <br>
#
# ___
# <div class="alert alert-block alert-info">
# <b>Tip:</b> In this section, clearly define the problem you are trying to solve, provide context about its importance, and briefly describe the dataset.
# </div>
#
# ## Problem Definition
# 1. Define the problem you are addressing.
# 2. Explain why this problem is important.
# 3. Describe the dataset and its source.
# 4. Define full scope to avoid scope creep
#
# <br>
#
# ___
# <div class="alert alert-block alert-warning">
# <b>Example:</b>
#
# - Ensure the problem statement is clear and concise.
# - Identify the stakeholders and their needs.
# - Consider the potential impact and benefits of solving the problem.
# - Be aware of any assumptions and limitations.
# - Make sure the problem is feasible to solve with the available data and resources.
# <br>
# </div>
#
# ___
#
# </details>

# %% [markdown]
# # Problem Introduction
#
# <details open> <summary> Details </summary>
# <br>
#
# ___
#
# 1. Loading the Data: Start by loading the dataset and inspecting its structure.
# 1. Data Cleaning: Remove anomalous values, such as negative values for heart rate (e.g., -120).
# 1. Handling Missing Data: Identify missing values and decide how to handle them (e.g., imputation, or removal).
# 1. Transforming: Converting categorical variables to numerical values.
# 1. Summarizing and Visualization: visualize or summarize data using different plots, such as histograms or boxplots, to better understand distributions and relationships.
#
# <div class="alert alert-block alert-info">
# <b>Tip:</b> Follow these steps systematically to ensure your data is clean, well-prepared, and ready for analysis. Always visualize your data to uncover hidden patterns and insights.
# </div>
#
# </details>

# %% [markdown]
# # Motivation
#
# <details open> <summary> Details </summary>
# <br>
#
# ___
#
# Define clearly what you are doing and the outcome you are hoping to achieve
#
# <div class="alert alert-block alert-success">
# <b>Tip:</b> When setting up a motivation for a project involving Exploratory Data Analysis (EDA), consider the following:
#
# - **Objective**: Clearly state the objective of your project. What specific questions are you trying to answer with the data?
# - **Importance**: Explain why this analysis is important. How will the insights gained from the project help in solving this problem and making decisions?
# - **Dataset Overview**: Provide a brief overview of the dataset, including its source, size, and key features.
# - **Expected Outcomes**: Describe the expected outcomes of the EDA. What kind of patterns, trends, or anomalies are you looking to uncover?
# </div>

# %% [markdown]
# <details>
# <summary h1>Tasks</summary>
# <br>
#
# For the following dataset, you have a binary target variable (first column) and five predictor variables.
# Imagine you are beginning a classification exercise from the very beginning. Now, create a new Notebook to reflect ALL the steps you believe you should complete to arrive at a more comprehensive and potentially trustworthy outcome. Build a TEMPLATE that you can reuse over and over again in the future.
# Use markdown cells to create a well-organized outline. You should end up with sections in your Jupyter Notebook at Google Colab that reflect ALL major steps in the ML process.
# I expect to see at least FOUR major sections:
# 1. **Problem Introduction & Motivation (No Code Needed)**: you should clearly define the problem you are trying to solve, provide context about its importance, and briefly describe the dataset.
# 2. **Data Preparation (EDA) (Code Required)**
#     - Loading the Data: Start by loading the dataset and inspecting its structure.
#     - Data Cleaning: Remove anomalous values, such as negative values for heart rate (e.g., -120).
#     - Handling Missing Data: Identify missing values and decide how to handle them (e.g., imputation, or removal).
#     - Transforming: Converting categorical variables to numerical values.
#     - Summarizing and Visualization: visualize or summarize data using different plots, such as histograms or boxplots, to better understand distributions and relationships.
# 3. **Model Selection (No Code Needed)**: pick one ML model that you think might be appropriate for this task (just try your best; there is no need to provide any coding now).
# 4. **Model Evaluation (No Code Needed)**: describe possible ways to evaluate model performance (just try your best; there is no need to provide any coding now).
#
# </details>

# %% [markdown]
# # Summary
#
# <details open>
# <summary>Summary of the Workflow</summary>
# <br>
#
# ___
#
# This notebook is designed to provide a comprehensive template for a machine learning project. It includes the following sections:
#
# 1. **Problem Introduction & Motivation**: Clearly define the problem, provide context, and describe the dataset.
# 2. **Data Preparation (EDA)**: Load the data, clean it, handle missing values, transform variables, and visualize the data.
# 3. **Model Selection**: Choose an appropriate machine learning model based on the problem and data characteristics.
# 4. **Model Evaluation**: Describe the metrics and methods used to evaluate the model's performance.
#
# Each section is structured to guide you through the necessary steps to ensure your project is well-organized, transparent, and replicable.
#
# </details>

# %% [markdown]
# # Data Preparation (EDA)

# %% [markdown]
# ## Import the necessary packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tkinter import Tk
from tkinter.filedialog import askopenfilename

# %% [markdown]
# ## Load the dataset

# %%
# Prompt to choose a file
Tk().withdraw()  # We don't want a full GUI, so keep the root window from appearing
file_path = askopenfilename()  # Show an "Open" dialog box and return the path to the selected file

# Load the dataset
df = pd.read_csv(file_path)

# %% [markdown]
# ## Understand the data, get a snapshot and see the data types

# %%
# Inspect the structure of the dataset
print(df.head())
print(df.info())
print(df.describe())

# Identify missing values
missing_values = df.isnull().sum()
print(missing_values)

# Display rows with missing values
rows_with_missing_values = df[df.isnull().any(axis=1)]
print(rows_with_missing_values)
# Out:
#    heart_disease   age     sex  max_heart_rate angina_level  non_anginal_pain
# 0              0  69.0    male             131           No                 0
# 1              0  69.0  female             151           No                 0
# 2              0   NaN  female             114           No                 0
# 3              1  65.0    male             174           No                 0
# 4              0  64.0    male             144         Mild                 0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297 entries, 0 to 296
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   heart_disease     297 non-null    int64
#  1   age               268 non-null    float64
#  2   sex               297 non-null    object
#  3   max_heart_rate    297 non-null    int64
#  4   angina_level      277 non-null    object
#  5   non_anginal_pain  297 non-null    int64
# ...

# %% [markdown]
# ## Data Cleaning

# %%
# Data Cleaning
# Remove anomalous values
df = df[df['max_heart_rate'] >= 0]
df = df[df['age'] >= 0]
df = df[df['non_anginal_pain'] >= 0]

# Change datatype of age from float to integer
df['age'] = df['age'].astype(int)

# Fill missing values in angina_level with 'n/a'
df['angina_level'] = df['angina_level'].fillna('n/a')

# One-hot encoding for angina_level
df = pd.get_dummies(df, columns=['angina_level'], drop_first=False)
# Out:
# heart_disease        0
# age                  0
# sex                  0
# max_heart_rate       0
# angina_level        18
# non_anginal_pain     0
# dtype: int64

# %% [markdown]
# # Handling Missing Data

# %%
# Identify missing values
missing_values = df.isnull().sum()
print(missing_values)

print(df.head())
# If any is missing, drop the row
# df = df.dropna()
# Out:
# heart_disease          0
# age                    0
# sex                    0
# max_heart_rate         0
# non_anginal_pain       0
# angina_level_Mild      0
# angina_level_No        0
# angina_level_Severe    0
# angina_level_n/a       0
# dtype: int64
#    heart_disease  age     sex  max_heart_rate  non_anginal_pain  \
# 0              0   69    male             131                 0
# 1              0   69  female             151                 0
# 3              1   65    male             174                 0
# 4              0   64    male             144                 0
# 5              0   64    male             155                 0
#
#    angina_level_Mild  angina_level_No  angina_level_Severe  angina_level_n/a
# 0              False             True                False             False
# 1              False             True                False             False
# 3              False             True                False             False
# ...

# %% [markdown]
# # Transforming

# %%
# Convert categorical variables to numerical values
df = pd.get_dummies(df, drop_first=True)

# %% [markdown]
# # Summarizing and Visualization

# %%
# Visualize distributions
df.hist(bins=30, figsize=(20, 15))
plt.show()

# Visualize relationships
sns.pairplot(df)
plt.show()

# %% [markdown]
# # Model Selection
# ## Model Choice
#
# <details open>
# <summary>Pick one ML model that you think might be appropriate for this task.</summary>
# <br>
#
# <div class="alert alert-block alert-info">
# <b>Tip:</b> When choosing a model, consider the nature of your data, the problem you are trying to solve, and the assumptions of the model.
# </div>
#
# ### Chosen Model
# ___
#
# - **Model**: Discuss the chosen model and why it might be suitable for this problem.
# - **Assumptions**: Mention any assumptions or considerations for this model.
# - **Data Characteristics**: Consider the nature of your data (e.g., size, type, distribution) and how it influences model choice.
# - **Problem Type**: Identify the type of problem (e.g., classification, regression, clustering) and select a model accordingly.
# - **Performance Metrics**: Think about the evaluation metrics that are important for your task and how different models perform against these metrics.
# - **Computational Resources**: Take into account the computational resources available and the complexity of the model.
# - **Interpretability**: Consider the need for model interpretability and how it impacts the choice of model.
# - **Domain Knowledge**: Leverage domain knowledge to guide the selection of a model that is known to perform well for similar tasks.
#
# <br>
# <div class="alert alert-block alert-warning">
# <b>Example:</b> For a binary classification problem like predicting heart disease, you might choose a Logistic Regression model due to its simplicity and interpretability.
# </div>
#
# </details>

# %% [markdown]
# ## Model Evaluation
#
# <details open>
# <summary>Describe possible ways to evaluate model performance.</summary>
# <br>
#
# <div class="alert alert-block alert-info">
# <b>Tip:</b> Evaluation metrics help you understand how well your model is performing and where it might be improved.
# </div>
#
# ### Evaluation Metrics
# - **Accuracy**: The ratio of correctly predicted instances to the total instances. It is a good measure when the classes are well balanced.
# - **Precision**: The ratio of correctly predicted positive observations to the total predicted positives. It is useful when the cost of false positives is high.
# - **Recall (Sensitivity)**: The ratio of correctly predicted positive observations to all the observations in the actual class. It is useful when the cost of false negatives is high.
# - **F1-Score**: The weighted average of Precision and Recall. It is useful when you need a balance between Precision and Recall.
# - **ROC-AUC Score**: The area under the Receiver Operating Characteristic curve. It provides an aggregate measure of performance across all classification thresholds.
#
# ### Importance
# - **Accuracy**: Important for getting a general sense of model performance but can be misleading with imbalanced datasets.
# - **Precision**: Important in scenarios where false positives are costly, such as spam detection.
# - **Recall**: Important in scenarios where false negatives are costly, such as medical diagnosis.
# - **F1-Score**: Provides a balance between Precision and Recall, useful when you need to consider both metrics.
# - **ROC-AUC Score**: Useful for comparing models and understanding the trade-off between true positive rate and false positive rate.
#
# <div class="alert alert-block alert-warning">
# <b>Example:</b> For a medical diagnosis problem, precision and recall might be more important than accuracy because false positives and false negatives have different implications.
# </div>
#
# </details>
